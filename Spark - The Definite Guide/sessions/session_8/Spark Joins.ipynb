# %% [markdown]
# # Joins

# %% [markdown]
# Los joins (funcionalidades para juntar dos o más tablas) son muy esenciales en Spark SQL ya que por lo general se trabaja con diferentes fuentes de datos.
#
# Es necesario comprender los tipos de joins que nos posibilita el Spark SQL y el cómo Spark los ejecuta. El objetivo de este notebook es hacer un tutorial de los diferentes tipos de joins y de las ventajas y limitaciones de cada uno de estos.

# %% [markdown]
# ## 1. Join en los DataFrames
#
# Los joins en Spark SQL se hacen mediante el método ´join´ del DataFrame de la siguiente manera:
#
# `DataFrame.join(other, on=None, how=None)`
#
# Es necesario definir como argumento principal el dataframe que representaría el lado derecho del join (argumento *other*). Los argumentos opcionales representan el criterio (argumento *on*) y el tipo de join (argumento *how*).

# %% [markdown]
# # 2. Elementos de un join
#
# Al momento de hacer un join, es necesario tener en cuenta 2 elementos:
# * La condición del join
# * El tipo del join

# %% [markdown]
# ### 2.1 La condición del join
#
# El join también puede ser influenciado por el operador que se utiliza al especificar la condición de un join:
# * El operador de igualdad (=), en una operación denominada ***equi join*** (por ejemplo, **cliente.id = transaccion.id**)
# * Otros operadores (>, <, >=, <=), en una operación denominada ***non equi join*** (por ejemplo, **cliente.id > transaccion.id**)
#
# Para propósitos de este notebook, nos enfocaremos en operaciones de **equi join**.

# %% [markdown]
# ### 2.2 El tipo del join
#
# Spark soporta una variedad de tipos de joins. Las más comunes serían:
# * Inner Join
# * Outer Join
# * Semi Join
# * Anti Join
# * Cross (Cartesian) Join
#
# Ilustraremos con ejemplos cada tipo del join.

# %%
# Importar las funciones del Spark SQL
from pyspark.sql.functions import *
from pyspark.sql import SparkSession

# Create SparkSession
spark = SparkSession.builder \
    .master("local") \
    .appName("Chapter 8 - Joins") \
    .getOrCreate()

# %%
# Alterar el número de particiones shuffle
spark.conf.set("spark.sql.shuffle.partitions", 10)

# %%
# Cargar los dataframes

customers = spark.read.options(header='True', inferSchema='True').csv("../../data/customers.csv")
transactions = spark.read.options(header='True', inferSchema='True').csv("../../data/transactions.csv")

# Convertir el tipo de la columna "Product" a array
transactions = transactions.withColumn("Product", split(col("Product"), ",").cast("array<string>"))

# %%
# Visualizar la tabla de clientes
customers.toPandas()
# Out:
#    Id CustomerType FirstName MiddleName   LastName
# 0  12      Diamond     Elena       None      Moore
# 1  13       Bronze      Paul   Williams       Page
# 2  14       Bronze    Albert       None     Thomas
# 3  15       Bronze    Sandra  Elizabeth      Faith
# 4  16         Gold    Robert       None  Alexander

# %%
# Visualizar la tabla de transacciones
transactions.toPandas()
# Out:
#    TransactionId  CustomerId             Merchant  \
# 0              1          11        amazon.com.uk
# 1              2          12  marksandspencer.com
# 2              3          14        amazon.com.uk
# 3              4          12            tesco.com
# 4              5          13         apple.com.uk
# 5              6          17            e.leclerc
# 6              7          14          zalando.com
# 7              8          13          zalando.com
# 8              9          15           amazon.com
#
#                        Product  TotalAmount       Date
# 0               [shirt, shoes]          150 2021-04-08
# 1               [short, shirt]           50 2021-04-08
# 2        [smartphone, charger]          450 2021-04-09
# 3  [fruits, meat, wholegrains]           75 2021-04-09
# 4         [charger, headphone]          120 2021-04-09
# 5                 [smartphone]          550 2021-04-10
# 6                      [shoes]           45 2021-04-11
# 7          [handbag, jumpsuit]          250 2021-04-13
# 8                      [books]           50 2021-04-13

# %% [markdown]
# ### 3.1 Inner join
#
# El **inner join** es una expresión que mantiene las filas cuyos valores se encuentran ambas tablas. Si los valores de la columna clave no se muestra en las dos tablas, los respectivos registros no se muestran en el resultado del join.

# %% [markdown]
# ![img](https://raw.githubusercontent.com/kauvinlucas/Spark-StudyClub/main/Spark%20-%20The%20Definite%20Guide/assets/inner.png)

# %% [markdown]
# Por ser una expresión predeterminada, se puede directamente utilizar el join sin necesidad de especificar el tipo.

# %%
customers.join(transactions, customers["Id"] == transactions["CustomerId"], how="inner").toPandas()
# Out:
#    Id CustomerType FirstName MiddleName LastName  TransactionId  CustomerId  \
# 0  12      Diamond     Elena       None    Moore              2          12
# 1  14       Bronze    Albert       None   Thomas              3          14
# 2  12      Diamond     Elena       None    Moore              4          12
# 3  13       Bronze      Paul   Williams     Page              5          13
# 4  14       Bronze    Albert       None   Thomas              7          14
# 5  13       Bronze      Paul   Williams     Page              8          13
# 6  15       Bronze    Sandra  Elizabeth    Faith              9          15
#
#               Merchant                      Product  TotalAmount       Date
# 0  marksandspencer.com               [short, shirt]           50 2021-04-08
# 1        amazon.com.uk        [smartphone, charger]          450 2021-04-09
# 2            tesco.com  [fruits, meat, wholegrains]           75 2021-04-09
# 3         apple.com.uk         [charger, headphone]          120 2021-04-09
# 4          zalando.com                      [shoes]           45 2021-04-11
# 5          zalando.com          [handbag, jumpsuit]          250 2021-04-13
# 6           amazon.com                      [books]           50 2021-04-13

# %% [markdown]
# ### 3.2 Outer Joins
#
# Retornas las filas que contienen los valores de la clave en ambas, sino retorna valores nulos.

# %% [markdown]
# ![img](https://github.com/kauvinlucas/Spark-StudyClub/blob/main/Spark%20-%20The%20Definite%20Guide/assets/outer.png?raw=true)

# %% [markdown]
# ### 3.2.1 Left Outer Join
#
# Retorna todos los registros de la tabla del lado izquierdo del join y los registros del lado derecho que contengan las mismos valores de la clave, sino returna valores nulos del lado derecho.

# %%
customers.join(transactions, customers["Id"] == transactions["CustomerId"], how="left_outer").toPandas()
# Out:
#    Id CustomerType FirstName MiddleName   LastName  TransactionId  CustomerId  \
# 0  12      Diamond     Elena       None      Moore            4.0        12.0
# 1  12      Diamond     Elena       None      Moore            2.0        12.0
# 2  13       Bronze      Paul   Williams       Page            8.0        13.0
# 3  13       Bronze      Paul   Williams       Page            5.0        13.0
# 4  14       Bronze    Albert       None     Thomas            7.0        14.0
# 5  14       Bronze    Albert       None     Thomas            3.0        14.0
# 6  15       Bronze    Sandra  Elizabeth      Faith            9.0        15.0
# 7  16         Gold    Robert       None  Alexander            NaN         NaN
#
#               Merchant                      Product  TotalAmount       Date
# 0            tesco.com  [fruits, meat, wholegrains]         75.0 2021-04-09
# 1  marksandspencer.com               [short, shirt]         50.0 2021-04-08
# 2          zalando.com          [handbag, jumpsuit]        250.0 2021-04-13
# 3         apple.com.uk         [charger, headphone]        120.0 2021-04-09
# 4          zalando.com                      [shoes]         45.0 2021-04-11
# 5        amazon.com.uk        [smartphone, charger]        450.0 2021-04-09
# 6           amazon.com                      [books]         50.0 2021-04-13
# 7                 None                         None          NaN        NaT

# %% [markdown]
# ### 3.2.1 Right Outer Join
#
# Retorna todos los registros de la tabla del lado derecho del join y los registros del lado izquierdo que contengan las mismos valores de la clave, sino returna valores nulos del lado derecho.

# %%
customers.join(transactions, customers["Id"] == transactions["CustomerId"], how="rightouter").toPandas()
# Out:
#      Id CustomerType FirstName MiddleName LastName  TransactionId  CustomerId  \
# 0   NaN         None      None       None     None              1          11
# 1  12.0      Diamond     Elena       None    Moore              2          12
# 2  14.0       Bronze    Albert       None   Thomas              3          14
# 3  12.0      Diamond     Elena       None    Moore              4          12
# 4  13.0       Bronze      Paul   Williams     Page              5          13
# 5   NaN         None      None       None     None              6          17
# 6  14.0       Bronze    Albert       None   Thomas              7          14
# 7  13.0       Bronze      Paul   Williams     Page              8          13
# 8  15.0       Bronze    Sandra  Elizabeth    Faith              9          15
#
#               Merchant                      Product  TotalAmount       Date
# 0        amazon.com.uk               [shirt, shoes]          150 2021-04-08
# 1  marksandspencer.com               [short, shirt]           50 2021-04-08
# 2        amazon.com.uk        [smartphone, charger]          450 2021-04-09
# 3            tesco.com  [fruits, meat, wholegrains]           75 2021-04-09
# 4         apple.com.uk         [charger, headphone]          120 2021-04-09
# 5            e.leclerc                 [smartphone]          550 2021-04-10
# 6          zalando.com                      [shoes]           45 2021-04-11
# 7          zalando.com          [handbag, jumpsuit]          250 2021-04-13
# 8           amazon.com                      [books]           50 2021-04-13

# %% [markdown]
# ### 3.2.1 Full Outer Join
#
# Retorna todos los registros de la tabla del lado derecho del join y todos los registros del lado izquierdo. Si los valores de la columna clave no coincide con la otra tabla, devuelve valores nulos de la otra tabla.

# %%
customers.join(transactions, customers["Id"] == transactions["CustomerId"], how="outer").toPandas()
# Out:
#      Id CustomerType FirstName MiddleName   LastName  TransactionId  \
# 0   NaN         None      None       None       None            1.0
# 1  12.0      Diamond     Elena       None      Moore            2.0
# 2  12.0      Diamond     Elena       None      Moore            4.0
# 3  15.0       Bronze    Sandra  Elizabeth      Faith            9.0
# 4  13.0       Bronze      Paul   Williams       Page            5.0
# 5  13.0       Bronze      Paul   Williams       Page            8.0
# 6  14.0       Bronze    Albert       None     Thomas            3.0
# 7  14.0       Bronze    Albert       None     Thomas            7.0
# 8  16.0         Gold    Robert       None  Alexander            NaN
# 9   NaN         None      None       None       None            6.0
#
#    CustomerId             Merchant                      Product  TotalAmount  \
# 0        11.0        amazon.com.uk               [shirt, shoes]        150.0
# 1        12.0  marksandspencer.com               [short, shirt]         50.0
# 2        12.0            tesco.com  [fruits, meat, wholegrains]         75.0
# 3        15.0           amazon.com                      [books]         50.0
# 4        13.0         apple.com.uk         [charger, headphone]        120.0
# 5        13.0          zalando.com          [handbag, jumpsuit]        250.0
# 6        14.0        amazon.com.uk        [smartphone, charger]        450.0
# 7        14.0          zalando.com                      [shoes]         45.0
# 8         NaN                 None                         None          NaN
# 9        17.0            e.leclerc                 [smartphone]        550.0
#
#         Date
# 0 2021-04-08
# 1 2021-04-08
# 2 2021-04-09
# 3 2021-04-13
# 4 2021-04-09
# 5 2021-04-13
# 6 2021-04-09
# 7 2021-04-11
# 8        NaT
# 9 2021-04-10

# %% [markdown]
# ### 3.3 Left & Right Semi Joins
#
# Los Left Semi Joins funcionan de manera similar al Inner Join, pero muestran solo los registros de la tabla del lado izquierdo.
#
# En otras palabras, evaluan si hay registros con los mismos valores en la columna clave en ambas tablas, y retornan solamente los registros del lado izquierdo del join si hay registros con la misma clave en el lado derecho.
#
# El **Right Semi Join** es una operación que se realiza sobre el lado derecho del join. En este caso, sólo hay que utilizar el método join sobre el otro DataFrame.

# %% [markdown]
# ![img](https://github.com/kauvinlucas/Spark-StudyClub/blob/main/Spark%20-%20The%20Definite%20Guide/assets/semi.png?raw=true)

# %%
# Left Semi Join
customers.join(transactions, customers["Id"] == transactions["CustomerId"], how="left_semi").toPandas()
# Out:
#    Id CustomerType FirstName MiddleName LastName
# 0  12      Diamond     Elena       None    Moore
# 1  13       Bronze      Paul   Williams     Page
# 2  14       Bronze    Albert       None   Thomas
# 3  15       Bronze    Sandra  Elizabeth    Faith

# %%
# Right Semi Join
transactions.join(customers, transactions["CustomerId"] == customers["Id"], how="left_semi").toPandas()
# Out:
#    TransactionId  CustomerId             Merchant  \
# 0              2          12  marksandspencer.com
# 1              3          14        amazon.com.uk
# 2              4          12            tesco.com
# 3              5          13         apple.com.uk
# 4              7          14          zalando.com
# 5              8          13          zalando.com
# 6              9          15           amazon.com
#
#                        Product  TotalAmount       Date
# 0               [short, shirt]           50 2021-04-08
# 1        [smartphone, charger]          450 2021-04-09
# 2  [fruits, meat, wholegrains]           75 2021-04-09
# 3         [charger, headphone]          120 2021-04-09
# 4                      [shoes]           45 2021-04-11
# 5          [handbag, jumpsuit]          250 2021-04-13
# 6                      [books]           50 2021-04-13

# %% [markdown]
# ### 3.4 Left & Right Anti Joins
#
# **Los Left Anti Joins son opuestos a los Left Semi Joins**. Evaluan si hay registros con los mismos valores en la columna clave en ambas tablas, pero retornan solamente los registros del lado izquierdo del join si **NO** hay registros correspondientes en el lado derecho.
#
# El Right Anti Join es una operación que se realiza sobre el lado derecho del join. En este caso, sólo hay que utilizar el método join sobre el otro DataFrame.

# %% [markdown]
# ![img](https://github.com/kauvinlucas/Spark-StudyClub/blob/main/Spark%20-%20The%20Definite%20Guide/assets/anti.png?raw=true)

# %%
# Left Anti Join
customers.join(transactions, customers["Id"] == transactions["CustomerId"], how="left_anti").toPandas()
# Out:
#    Id CustomerType FirstName MiddleName   LastName
# 0  16         Gold    Robert       None  Alexander

# %%
# Right Anti Join
transactions.join(customers, transactions["CustomerId"] == customers["Id"], how="left_anti").toPandas()
# Out:
#    TransactionId  CustomerId       Merchant         Product  TotalAmount  \
# 0              1          11  amazon.com.uk  [shirt, shoes]          150
# 1              6          17      e.leclerc    [smartphone]          550
#
#         Date
# 0 2021-04-08
# 1 2021-04-10

# %% [markdown]
# ### 3.5 Cross Join

# %% [markdown]
# Los Cross Joins (o Cartesian Joins) unen cada uno de los registros de una tabla con cada uno de los registros de la otra tabla, haciendo así un producto cartesiano en todos los registros.
#
# Por ejemplo, si deseo juntar una tabla de 1000 registros con otra tabla de 1000 registros, el Cross Join resultaría en 1.000.000 de registros.
#
# Esta "explosión" de registros es la razón por la que Spark internamente opta por hacer un Inner Join en lugar del Cross Join.

# %%
# Cross Join
customers.join(transactions, customers["Id"] == transactions["CustomerId"], how="cross").toPandas()
# Out:
#    Id CustomerType FirstName MiddleName LastName  TransactionId  CustomerId  \
# 0  12      Diamond     Elena       None    Moore              2          12
# 1  14       Bronze    Albert       None   Thomas              3          14
# 2  12      Diamond     Elena       None    Moore              4          12
# 3  13       Bronze      Paul   Williams     Page              5          13
# 4  14       Bronze    Albert       None   Thomas              7          14
# 5  13       Bronze      Paul   Williams     Page              8          13
# 6  15       Bronze    Sandra  Elizabeth    Faith              9          15
#
#               Merchant                      Product  TotalAmount       Date
# 0  marksandspencer.com               [short, shirt]           50 2021-04-08
# 1        amazon.com.uk        [smartphone, charger]          450 2021-04-09
# 2            tesco.com  [fruits, meat, wholegrains]           75 2021-04-09
# 3         apple.com.uk         [charger, headphone]          120 2021-04-09
# 4          zalando.com                      [shoes]           45 2021-04-11
# 5          zalando.com          [handbag, jumpsuit]          250 2021-04-13
# 6           amazon.com                      [books]           50 2021-04-13

# %% [markdown]
# Si no especifico la condición del join, Spark no lo haría y retornaría un error:

# %%
customers.join(transactions, how="cross").toPandas()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# /opt/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#
# /opt/spark/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#
# Py4JJavaError: An error occurred while calling o431.join.
# : java.lang.IllegalArgumentException: requirement failed: Unsupported using join type Cross
# 	at scala.Predef$.require(Predef.scala:224)
# 	at org.apache.spark.sql.catalyst.plans.UsingJoin.<init>(joinTypes.scala:105)
# 	at org.apache.spark.sql.Dataset.join(Dataset.scala:942)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:748)
#
#
# During handling of the above exception, another exception occurred:
#
# IllegalArgumentException                  Traceback (most recent call last)
# <ipython-input-62-54ed45fab26f> in <module>()
# ----> 1 customers.join(transactions, how="cross").toPandas()
#
# /opt/spark/python/pyspark/sql/dataframe.py in join(self, other, on, how)
#    1047                 on = self._jseq([])
#    1048             assert isinstance(how, basestring), "how should be basestring"
# -> 1049             jdf = self._jdf.join(other._jdf, on, how)
#    1050         return DataFrame(jdf, self.sql_ctx)
#    1051
#
# /opt/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# /opt/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#      77                 raise QueryExecutionException(s.split(': ', 1)[1], stackTrace)
#      78             if s.startswith('java.lang.IllegalArgumentException: '):
# ---> 79                 raise IllegalArgumentException(s.split(': ', 1)[1], stackTrace)
#      80             raise
#      81     return deco
#
# IllegalArgumentException: 'requirement failed: Unsupported using join type Cross'

# %% [markdown]
# Para forzar un Cross Join, hay que hacerlo de manera explícita mediante el método **crossJoin**:

# %%
customers.crossJoin(transactions).toPandas()
# Out:
#     Id CustomerType FirstName MiddleName   LastName  TransactionId  \
# 0   12      Diamond     Elena       None      Moore              1
# 1   13       Bronze      Paul   Williams       Page              1
# 2   14       Bronze    Albert       None     Thomas              1
# 3   15       Bronze    Sandra  Elizabeth      Faith              1
# 4   16         Gold    Robert       None  Alexander              1
# 5   12      Diamond     Elena       None      Moore              2
# 6   13       Bronze      Paul   Williams       Page              2
# 7   14       Bronze    Albert       None     Thomas              2
# 8   15       Bronze    Sandra  Elizabeth      Faith              2
# 9   16         Gold    Robert       None  Alexander              2
# 10  12      Diamond     Elena       None      Moore              3
# 11  13       Bronze      Paul   Williams       Page              3
# 12  14       Bronze    Albert       None     Thomas              3
# 13  15       Bronze    Sandra  Elizabeth      Faith              3
# 14  16         Gold    Robert       None  Alexander              3
# 15  12      Diamond     Elena       None      Moore              4
# 16  13       Bronze      Paul   Williams       Page              4
# 17  14       Bronze    Albert       None     Thomas              4
# 18  15       Bronze    Sandra  Elizabeth      Faith              4
# 19  16         Gold    Robert       None  Alexander              4
# 20  12      Diamond     Elena       None      Moore              5
# 21  13       Bronze      Paul   Williams       Page              5
# 22  14       Bronze    Albert       None     Thomas              5
# 23  15       Bronze    Sandra  Elizabeth      Faith              5
# 24  16         Gold    Robert       None  Alexander              5
# 25  12      Diamond     Elena       None      Moore              6
# 26  13       Bronze      Paul   Williams       Page              6
# 27  14       Bronze    Albert       None     Thomas              6
# 28  15       Bronze    Sandra  Elizabeth      Faith              6
# 29  16         Gold    Robert       None  Alexander              6
# 30  12      Diamond     Elena       None      Moore              7
# 31  13       Bronze      Paul   Williams       Page              7
# 32  14       Bronze    Albert       None     Thomas              7
# 33  15       Bronze    Sandra  Elizabeth      Faith              7
# 34  16         Gold    Robert       None  Alexander              7
# 35  12      Diamond     Elena       None      Moore              8
# 36  13       Bronze      Paul   Williams       Page              8
# 37  14       Bronze    Albert       None     Thomas              8
# 38  15       Bronze    Sandra  Elizabeth      Faith              8
# 39  16         Gold    Robert       None  Alexander              8
# 40  12      Diamond     Elena       None      Moore              9
# 41  13       Bronze      Paul   Williams       Page              9
# 42  14       Bronze    Albert       None     Thomas              9
# 43  15       Bronze    Sandra  Elizabeth      Faith              9
# 44  16         Gold    Robert       None  Alexander              9
#
#     CustomerId             Merchant                      Product  TotalAmount  \
# 0           11        amazon.com.uk               [shirt, shoes]          150
# 1           11        amazon.com.uk               [shirt, shoes]          150
# 2           11        amazon.com.uk               [shirt, shoes]          150
# 3           11        amazon.com.uk               [shirt, shoes]          150
# 4           11        amazon.com.uk               [shirt, shoes]          150
# 5           12  marksandspencer.com               [short, shirt]           50
# 6           12  marksandspencer.com               [short, shirt]           50
# 7           12  marksandspencer.com               [short, shirt]           50
# 8           12  marksandspencer.com               [short, shirt]           50
# 9           12  marksandspencer.com               [short, shirt]           50
# 10          14        amazon.com.uk        [smartphone, charger]          450
# 11          14        amazon.com.uk        [smartphone, charger]          450
# 12          14        amazon.com.uk        [smartphone, charger]          450
# 13          14        amazon.com.uk        [smartphone, charger]          450
# 14          14        amazon.com.uk        [smartphone, charger]          450
# 15          12            tesco.com  [fruits, meat, wholegrains]           75
# 16          12            tesco.com  [fruits, meat, wholegrains]           75
# 17          12            tesco.com  [fruits, meat, wholegrains]           75
# 18          12            tesco.com  [fruits, meat, wholegrains]           75
# 19          12            tesco.com  [fruits, meat, wholegrains]           75
# 20          13         apple.com.uk         [charger, headphone]          120
# 21          13         apple.com.uk         [charger, headphone]          120
# 22          13         apple.com.uk         [charger, headphone]          120
# 23          13         apple.com.uk         [charger, headphone]          120
# 24          13         apple.com.uk         [charger, headphone]          120
# 25          17            e.leclerc                 [smartphone]          550
# 26          17            e.leclerc                 [smartphone]          550
# 27          17            e.leclerc                 [smartphone]          550
# 28          17            e.leclerc                 [smartphone]          550
# 29          17            e.leclerc                 [smartphone]          550
# 30          14          zalando.com                      [shoes]           45
# 31          14          zalando.com                      [shoes]           45
# 32          14          zalando.com                      [shoes]           45
# 33          14          zalando.com                      [shoes]           45
# 34          14          zalando.com                      [shoes]           45
# 35          13          zalando.com          [handbag, jumpsuit]          250
# 36          13          zalando.com          [handbag, jumpsuit]          250
# 37          13          zalando.com          [handbag, jumpsuit]          250
# 38          13          zalando.com          [handbag, jumpsuit]          250
# 39          13          zalando.com          [handbag, jumpsuit]          250
# 40          15           amazon.com                      [books]           50
# 41          15           amazon.com                      [books]           50
# 42          15           amazon.com                      [books]           50
# 43          15           amazon.com                      [books]           50
# 44          15           amazon.com                      [books]           50
#
#          Date
# 0  2021-04-08
# 1  2021-04-08
# 2  2021-04-08
# 3  2021-04-08
# 4  2021-04-08
# 5  2021-04-08
# 6  2021-04-08
# 7  2021-04-08
# 8  2021-04-08
# 9  2021-04-08
# 10 2021-04-09
# 11 2021-04-09
# 12 2021-04-09
# 13 2021-04-09
# 14 2021-04-09
# 15 2021-04-09
# 16 2021-04-09
# 17 2021-04-09
# 18 2021-04-09
# 19 2021-04-09
# 20 2021-04-09
# 21 2021-04-09
# 22 2021-04-09
# 23 2021-04-09
# 24 2021-04-09
# 25 2021-04-10
# 26 2021-04-10
# 27 2021-04-10
# 28 2021-04-10
# 29 2021-04-10
# 30 2021-04-11
# 31 2021-04-11
# 32 2021-04-11
# 33 2021-04-11
# 34 2021-04-11
# 35 2021-04-13
# 36 2021-04-13
# 37 2021-04-13
# 38 2021-04-13
# 39 2021-04-13
# 40 2021-04-13
# 41 2021-04-13
# 42 2021-04-13
# 43 2021-04-13
# 44 2021-04-13

# %%
transactions.join(customers, transactions["CustomerId"] == customers["Id"], how="left_anti").explain()
# Out:
# == Physical Plan ==
# *(2) BroadcastHashJoin [CustomerId#1083], [Id#1062], LeftAnti, BuildRight
# :- *(2) Project [TransactionId#1082, CustomerId#1083, Merchant#1084, split(Product#1085, ,) AS Product#1094, TotalAmount#1086, Date#1087]
# :  +- *(2) FileScan csv [TransactionId#1082,CustomerId#1083,Merchant#1084,Product#1085,TotalAmount#1086,Date#1087] Batched: false, Format: CSV, Location: InMemoryFileIndex[file:/mnt/notebooks/data/transactions.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<TransactionId:int,CustomerId:int,Merchant:string,Product:string,TotalAmount:int,Date:times...
# +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)))
#    +- *(1) Project [Id#1062]
#       +- *(1) Filter isnotnull(Id#1062)
#          +- *(1) FileScan csv [Id#1062] Batched: false, Format: CSV, Location: InMemoryFileIndex[file:/mnt/notebooks/data/customers.csv], PartitionFilters: [], PushedFilters: [IsNotNull(Id)], ReadSchema: struct<Id:int>
